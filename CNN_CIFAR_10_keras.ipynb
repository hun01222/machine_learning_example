# %%
from keras.utils import np_utils
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Conv2D, pooling, Flatten, Dense

(train_images, train_labels), (test_images, test_labels)=cifar10.load_data()
print(train_images.shape, train_labels.shape, test_images.shape, test_labels.shape)
train_images=train_images.reshape(train_images.shape[0], 32,32,3).astype('float32')/255.0 # train_image_shape[0]: 데이터 몇개 있는지, 28*28, RGB:3
test_images=test_images.reshape(test_images.shape[0], 32,32,3).astype('float32')/255.0
train_labels=np_utils.to_categorical(train_labels)
test_labels=np_utils.to_categorical(test_labels)

model=Sequential()
model.add(Conv2D(32, (3,3), padding='same', strides=(1,1), activation='relu', input_shape=(32,32,3))) # filter 32개, filter size: (3,3)
print(model.output_shape) # (32*32)*32
model.add(pooling.MaxPool2D(pool_size=(2,2))) # 행 열 반으로 padding
print(model.output_shape) # (16*16)*32
model.add(Conv2D(64, (3,3), padding='same', strides=(1,1), activation='relu'))
print(model.output_shape) # (16*16)*64
model.add(pooling.MaxPool2D(pool_size=(2,2)))
print(model.output_shape) # (8*8)*64
model.add(Flatten())
model.add(Dense(10, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.fit(train_images, train_labels, epochs=5, batch_size=32, verbose=1)
_, accuracy=model.evaluate(test_images, test_labels)
print('Accuracy: ', accuracy)
model.summary()
# Out:
# (50000, 32, 32, 3) (50000, 1) (10000, 32, 32, 3) (10000, 1)
# (None, 32, 32, 32)
# (None, 16, 16, 32)
# (None, 16, 16, 64)
# (None, 8, 8, 64)
# Epoch 1/5
# 1563/1563 [==============================] - 83s 53ms/step - loss: 1.4130 - accuracy: 0.4990
# Epoch 2/5
# 1563/1563 [==============================] - 82s 53ms/step - loss: 1.0511 - accuracy: 0.6374
# Epoch 3/5
# 1563/1563 [==============================] - 82s 52ms/step - loss: 0.9277 - accuracy: 0.6809
# Epoch 4/5
# 1563/1563 [==============================] - 82s 53ms/step - loss: 0.8462 - accuracy: 0.7078
# Epoch 5/5
# ...
# 313/313 [==============================] - 5s 15ms/step - loss: 0.8922 - accuracy: 0.6948
# Accuracy:  0.6948000192642212
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_4 (Conv2D)           (None, 32, 32, 32)        896
#
#  max_pooling2d_4 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
# ...
