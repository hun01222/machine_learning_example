# %%
from keras.utils import np_utils
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense

(train_images, train_labels), (test_images, test_labels)=mnist.load_data()
print(train_images.shape, train_labels.shape, test_images.shape, test_labels.shape)
train_images=train_images.reshape(60000,784).astype("float32")/255.0
test_images=test_images.reshape(10000,784).astype("float32")/255.0
train_labels=np_utils.to_categorical(train_labels)
test_labels=np_utils.to_categorical(test_labels)

model=Sequential()
model.add(Dense(256, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(256, activation='relu')) # layer를 4개에서 7개로 늘리고
model.add(Dense(10, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])
model.fit(train_images, train_labels, epochs=10, batch_size=128, verbose=1) # 5번 반복학습에서 10번 반복학습으로 바꿨습니다.
_, accuracy=model.evaluate(test_images, test_labels)
print('Accuracy:', accuracy)
model.summary()
# Out:
# (60000, 28, 28) (60000,) (10000, 28, 28) (10000,)
# Epoch 1/10
# 469/469 [==============================] - 6s 11ms/step - loss: 1.8812 - accuracy: 0.4681
# Epoch 2/10
# 469/469 [==============================] - 5s 11ms/step - loss: 0.5050 - accuracy: 0.8562
# Epoch 3/10
# 469/469 [==============================] - 5s 11ms/step - loss: 0.3366 - accuracy: 0.9011
# Epoch 4/10
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2771 - accuracy: 0.9192
# Epoch 5/10
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2391 - accuracy: 0.9301
# Epoch 6/10
# 469/469 [==============================] - 5s 11ms/step - loss: 0.2099 - accuracy: 0.9388
# Epoch 7/10
# 469/469 [==============================] - 5s 11ms/step - loss: 0.1869 - accuracy: 0.9452
# Epoch 8/10
# 469/469 [==============================] - 5s 11ms/step - loss: 0.1683 - accuracy: 0.9502
# Epoch 9/10
# 469/469 [==============================] - 5s 11ms/step - loss: 0.1542 - accuracy: 0.9545
# ...
