# %%
# !pip install feedparser
# !pip install newspaper3k
# !pip install konlpy
# !pip install bs4
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cashe -fv
# !rm !/.cache/matplotlib -rf

import feedparser
from newspaper import Article
from konlpy.tag import Okt
from collections import Counter
from operator import eq
import numpy as np
from bs4 import BeautifulSoup

def crawl_rss(urls):
    arr_rss=[]
    for url in urls:
        print('[Crawl Rss] ', url)
        parse_rss=feedparser.parse(url)
        for p in parse_rss.entries:
            arr_rss.append({'title':p.title, 'link':p.link})
    return arr_rss

urls=["http://rss.etnews.com/Section901.xml", "http://rss.etnews.com/Section902.xml"]
article_list=crawl_rss(urls)

def crawl_article(url, language='ko'):
    print('[Crawl Article] ', url)
    var_article=Article(url, language=language)
    var_article.download()
    var_article.parse()
    return var_article.title, var_article.text

for article in article_list:
    _, text=crawl_article(article['link'])
    article['text']=text

def get_tags(text, ntags=50):
    num_unique_words=0
    num_most_freq=0
    ranking=0
    spliter=Okt()
    nouns=spliter.nouns(text)
    count=Counter(nouns)
    return_list=[]
    for n, c in count.most_common(ntags):
        ranking = ranking+1
        temp={'tag':n, 'count':c, 'ranking':ranking}
        return_list.append(temp)
        num_unique_words=num_unique_words+1
        if num_unique_words==1:
            num_most_freq=c
    return num_unique_words, num_most_freq, return_list

print('[Parsing Text]')
for article in article_list:
    num_unique_words, num_most_freq, tags=get_tags(article['text'], 1000)
    article['tags']=tags
    article['num_unique_words']=num_unique_words
    article['num_most_freq']=num_most_freq

def Howmanywords(request, tag):
    nWords=0
    nRanking=0
    for n in tag:
        noun=n['tag']
        count=n['count']
        rank=n['ranking']
        if eq(noun, request):
            nWords=count
            nRanking=rank
    return nWords, nRanking

print('Enter your query: ')
query=input()
for article in article_list:
    n, _=Howmanywords(query, article['tags'])
    if n!=0:
        print('TF:', n, article['title'], article['link'], '\n')
# Out:
# Requirement already satisfied: feedparser in /usr/local/lib/python3.7/dist-packages (6.0.8)
# Requirement already satisfied: sgmllib3k in /usr/local/lib/python3.7/dist-packages (from feedparser) (1.0.0)
# Requirement already satisfied: newspaper3k in /usr/local/lib/python3.7/dist-packages (0.2.8)
# Requirement already satisfied: jieba3k>=0.35.1 in /usr/local/lib/python3.7/dist-packages (from newspaper3k) (0.35.1)
# Requirement already satisfied: Pillow>=3.3.0 in /usr/local/lib/python3.7/dist-packages (from newspaper3k) (7.1.2)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.7/dist-packages (from newspaper3k) (2.8.2)
# Requirement already satisfied: nltk>=3.2.1 in /usr/local/lib/python3.7/dist-packages (from newspaper3k) (3.2.5)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from newspaper3k) (4.6.0)
# Requirement already satisfied: requests>=2.10.0 in /usr/local/lib/python3.7/dist-packages (from newspaper3k) (2.23.0)
# Requirement already satisfied: feedfinder2>=0.0.4 in /usr/local/lib/python3.7/dist-packages (from newspaper3k) (0.0.4)
# Requirement already satisfied: PyYAML>=3.11 in /usr/local/lib/python3.7/dist-packages (from newspaper3k) (3.13)
# Requirement already satisfied: tldextract>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from newspaper3k) (3.1.2)
# Requirement already satisfied: tinysegmenter==0.3 in /usr/local/lib/python3.7/dist-packages (from newspaper3k) (0.3)
# Requirement already satisfied: cssselect>=0.9.2 in /usr/local/lib/python3.7/dist-packages (from newspaper3k) (1.1.0)
# Requirement already satisfied: lxml>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from newspaper3k) (4.2.6)
# Requirement already satisfied: feedparser>=5.2.1 in /usr/local/lib/python3.7/dist-packages (from newspaper3k) (6.0.8)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from feedfinder2>=0.0.4->newspaper3k) (1.15.0)
# Requirement already satisfied: sgmllib3k in /usr/local/lib/python3.7/dist-packages (from feedparser>=5.2.1->newspaper3k) (1.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.10.0->newspaper3k) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.10.0->newspaper3k) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.10.0->newspaper3k) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.10.0->newspaper3k) (3.0.4)
# Requirement already satisfied: filelock>=3.0.8 in /usr/local/lib/python3.7/dist-packages (from tldextract>=2.0.1->newspaper3k) (3.4.0)
# Requirement already satisfied: requests-file>=1.4 in /usr/local/lib/python3.7/dist-packages (from tldextract>=2.0.1->newspaper3k) (1.5.1)
# Requirement already satisfied: konlpy in /usr/local/lib/python3.7/dist-packages (0.5.2)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.19.5)
# Requirement already satisfied: colorama in /usr/local/lib/python3.7/dist-packages (from konlpy) (0.4.4)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.2.6)
# Requirement already satisfied: beautifulsoup4==4.6.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.6.0)
# Requirement already satisfied: JPype1>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.3.0)
# Requirement already satisfied: tweepy>=3.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (3.10.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (3.10.0.2)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (2.23.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.10)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.7/dist-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from bs4) (4.6.0)
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.
# sudo: fc-cashe: command not found
# [Crawl Rss]  http://rss.etnews.com/Section901.xml
# [Crawl Rss]  http://rss.etnews.com/Section902.xml
# [Crawl Article]  https://www.etnews.com/20211126000177
# [Crawl Article]  https://www.etnews.com/20211126000178
# [Crawl Article]  https://www.etnews.com/20211126000153
# [Crawl Article]  https://www.etnews.com/20211126000130
# [Crawl Article]  https://www.etnews.com/20211126000128
# [Crawl Article]  https://www.etnews.com/20211126000103
# [Crawl Article]  https://www.etnews.com/20211126000094
# [Crawl Article]  https://www.etnews.com/20211126000080
# [Crawl Article]  https://www.etnews.com/20211126000063
# [Crawl Article]  https://www.etnews.com/20211126000055
# [Crawl Article]  https://www.etnews.com/20211126000054
# [Crawl Article]  https://www.etnews.com/20211126000053
# [Crawl Article]  https://www.etnews.com/20211126000052
# [Crawl Article]  https://www.etnews.com/20211126000027
# [Crawl Article]  https://www.etnews.com/20211126000047
# [Crawl Article]  https://www.etnews.com/20211126000042
# [Crawl Article]  https://www.etnews.com/20211126000039
# [Crawl Article]  https://www.etnews.com/20211126000041
# [Crawl Article]  https://www.etnews.com/20211126000036
# [Crawl Article]  https://www.etnews.com/20211126000035
# [Crawl Article]  https://www.etnews.com/20211126000034
# [Crawl Article]  https://www.etnews.com/20211126000025
# [Crawl Article]  https://www.etnews.com/20211126000024
# [Crawl Article]  https://www.etnews.com/20211126000023
# [Crawl Article]  https://www.etnews.com/20211126000016
# [Crawl Article]  https://www.etnews.com/20211126000007
# [Crawl Article]  https://www.etnews.com/20211126000005
# [Crawl Article]  https://www.etnews.com/20211126000001
# [Crawl Article]  https://www.etnews.com/20211125000065
# [Crawl Article]  https://www.etnews.com/20211125000244
# [Crawl Article]  https://www.etnews.com/20211126000159
# [Crawl Article]  https://www.etnews.com/20211127000001
# [Crawl Article]  https://www.etnews.com/20211126000177
# [Crawl Article]  https://www.etnews.com/20211126000178
# [Crawl Article]  https://www.etnews.com/20211126000180
# [Crawl Article]  https://www.etnews.com/20211126000176
# [Crawl Article]  https://www.etnews.com/20211126000175
# [Crawl Article]  https://www.etnews.com/20211126000174
# [Crawl Article]  https://www.etnews.com/20211126000173
# [Crawl Article]  https://www.etnews.com/20211126000172
# [Crawl Article]  https://www.etnews.com/20211126000171
# [Crawl Article]  https://www.etnews.com/20211126000170
# [Crawl Article]  https://www.etnews.com/20211126000169
# [Crawl Article]  https://www.etnews.com/20211126000168
# [Crawl Article]  https://www.etnews.com/20211126000165
# [Crawl Article]  https://www.etnews.com/20211126000157
# [Crawl Article]  https://www.etnews.com/20211126000106
# [Crawl Article]  https://www.etnews.com/20211126000105
# [Crawl Article]  https://www.etnews.com/20211126000101
# [Crawl Article]  https://www.etnews.com/20211126000100
# [Crawl Article]  https://www.etnews.com/20211126000058
# [Crawl Article]  https://www.etnews.com/20211126000057
# [Crawl Article]  https://www.etnews.com/20211126000056
# [Crawl Article]  https://www.etnews.com/20211126000164
# [Crawl Article]  https://www.etnews.com/20211126000163
# [Crawl Article]  https://www.etnews.com/20211126000161
# [Crawl Article]  https://www.etnews.com/20211126000158
# [Crawl Article]  https://www.etnews.com/20211126000156
# [Crawl Article]  https://www.etnews.com/20211126000154
# [Crawl Article]  https://www.etnews.com/20211126000153
# [Parsing Text]
# Enter your query:
# 고려대
